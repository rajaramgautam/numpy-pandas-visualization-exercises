# %% [markdown]
# # Exercises
#
# # Within your codeup-data-science directory, create a new directory named numpy-pandas-visualization-exercises. This will be where you do your work for this module. Initialize this directory as a local repository, create a repository on GitHub with the same name, link the remote, and push your work.
#
# # Do your work for this exercise in a jupyter notebook named matplotlib_exercises.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Use matplotlib to plot the following equation:
#
# - y=x^2−x+2
#
# # You'll need to write the code that generates the x and y points.
#
# # Add an anotation for the point 0, 0, the origin.

# %%
import numpy as np
# generating data

x = range (-100,100)
y =[x**2 -x+2 for x in x]
# plot x & y
plt.plot(x, y, c='green')

#add label 
plt.xlabel("x axis")
plt.ylabel("y axis")
# add annotation 
plt.annotate('Origin', xy = (0,0), xytext = (0, 1000), arrowprops ={})

plt.show()

# %% [markdown]
# # 2. Create and label 4 separate charts for the following equations (choose a range for x that makes sense):
#
# - y=√x
# - y=x^3
# - y=2^x
# - y=1/(x+1)
#
# # You can use functions from the math module to help implement some of the equations above.

# %%
x1 = range(0, 100)
y1 = [x**(1/2) for x in x1]
plt.plot(x1,y1)

plt.title(" $y = \sqrt{x}$")
plt.xlabel(" x axis")
plt.ylabel("y axis")
# Out:
# Text(0, 0.5, 'y axis')

# %%
x2 = range(0, 20)
y2 = [x**3 for x in x2]
plt.plot(x2,y2)
plt.title(" $y = x^3$")
plt.xlabel(" x axis")
plt.ylabel("y axis")
# Out:
# Text(0, 0.5, 'y axis')

# %%
x3 = range(1, 11)
y3 = [2**x for x in x3 ]
plt.plot(x3,y3)
plt.title(" $y = 2^x$")
plt.xlabel(" x axis")
plt.ylabel("y axis")
# Out:
# Text(0, 0.5, 'y axis')

# %%
x4 = range(1, 11)
y4 = [1/ (x+1) for x in x4]
plt.plot(x4,y4)
plt.title (" y = 1/(x+1)")
plt.xlabel(" x axis")
plt.ylabel("y axis")
# Out:
# Text(0, 0.5, 'y axis')

# %% [markdown]
# # 3. Combine the figures you created in the last step into one large figure with 4 subplots.

# %%
y1 = [x**(1/2) for x in x1]
y2 = [x**3 for x in x2]
y3= [x**3 for x in x3]
y4= y = [1/ (x+1) for x in x4]

plt.figure(figsize= (8,6))

plt.suptitle(" Combined Figures")

plt.subplot(2,2,1)

plt.plot(x1,y1, marker='_', c='green')
plt.grid(True, ls = '--')
plt.title(' y = x^(1/2)')

plt.subplot(2,2,2)
plt.plot(x2,y2, marker = '_', c='green')
plt.grid(True, ls = '--')
plt.title('y = x^3')

plt.subplot(2,2,3)
plt.plot(x3,y3, marker= '_', c='green')
plt.grid(True, ls = '--')
plt.title('y= 2^x')

plt.subplot(2,2,4)
plt.plot(x4,y4, marker= '*', c='green')
plt.grid(True, ls = '--')
plt.title('y= 1/(x+1)')
# Out:
# Text(0.5, 1.0, 'y= 1/(x+1)')

# %% [markdown]
# # 4. Combine the figures you created in the last step into one figure where each of the 4 equations has a different color for the points. Be sure to include a legend and an appropriate title for the figure.

# %%
y1 = [x**(1/2) for x in x1]
y2 = [x**3 for x in x2]
y3= [n**3 for n in x3]
y4= y = [1/ (x+1) for x in x4]

plt.plot(x1,y1, label = '$\sqrt{x}$', color = 'r', alpha = 0.7)
plt.plot(x2,y2, label = '$x^3$', color='b', alpha = 0.6)
plt.plot(x3,y3, label = '$2^{x}$', color='#FFA500', alpha = 0.4)
plt.plot(x4,y4, label = '$1/(x+1)$', color ='g', alpha = 0.4)


plt.ylim(0,10)
plt.xlim(0,10)
plt.title ('Combined')
plt.legend()
